# %%
from sklearn.svm import SVR
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
df=datasets.load_diabetes(as_frame=True).frame 
df.head()
# df.isnull().sum()
df.shape
# Out:
# (442, 11)

# %%
x=df.drop("target",axis=1)
y=df['target']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x.head()
y.head()

# Standard scaling  --->> Here we scaling y

y_scaler=StandardScaler()

y_train_scaled=y_scaler.fit_transform(y_train.values.reshape(-1,1)).ravel()
y_test_scaled=y_scaler.transform(y_test.values.reshape(-1,1)).ravel()

# %%
# model

model= SVR()
model.fit(x_train,y_train_scaled)
# Out:
# SVR()

# %%
y_pred_test_scaled=model.predict(x_test)
y_pred_train_scaled=model.predict(x_train)

# %%
# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  0.48844443151651884
# for train r2_score is  0.6596361676267712

# %%
# linear kernel

model= SVR(kernel="linear")
model.fit(x_train,y_train_scaled)

y_pred_test_scaled=model.predict(x_test)
y_pred_train_scaled=model.predict(x_train)

# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  0.4433761323833776
# for train r2_score is  0.45191229982475245

# %%
# polynomial kernel

model= SVR(kernel="poly")
model.fit(x_train,y_train_scaled)

y_pred_test_scaled=model.predict(x_test)
y_pred_train_scaled=model.predict(x_train)

# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  0.24203771038107758
# for train r2_score is  0.5790920834310542

# %%
#sigmoid kernel

model= SVR(kernel="sigmoid")
model.fit(x_train,y_train_scaled)

y_pred_test_scaled=model.predict(x_test)
y_pred_train_scaled=model.predict(x_train)

# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  -15.316808189576822
# for train r2_score is  -19.72119344073131

# %% [markdown]
# # Hyperparameter tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    "kernel":["linear","poly","rbf","sigmoid"],
    "C" : [1,2,3,3.2,3.3,3.4,3.5,4,4.5,5,10,100],
    "epsilon" :[0.001,0.01,0.1,1,0.2,0.3,0.5,5]
}

svr=SVR()

grid_search=GridSearchCV(svr, param_grid, scoring="r2", cv=5)

grid_search.fit(x_train,y_train_scaled)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 2, 3, 3.2, 3.3, 3.4, 3.5, 4, 4.5, 5, 10, 100],
#                          'epsilon': [0.001, 0.01, 0.1, 1, 0.2, 0.3, 0.5, 5],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='r2')

# %%
print("best parameters -->",grid_search.best_params_)
# Out:
# best parameters --> {'C': 10, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
# best model
best_model=SVR(C=10, epsilon=0.1, kernel="linear")

best_model.fit(x_train,y_train_scaled)
# Out:
# SVR(C=10, kernel='linear')

# %%
y_pred_test_scaled=best_model.predict(x_test)
y_pred_train_scaled=best_model.predict(x_train)

# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  0.47444183250401095
# for train r2_score is  0.5151066486918876

# %% [markdown]
# # LeaniarSVR --> it is a SVR with kernel is linear by default

# %%
# linearSVR

from sklearn.svm import LinearSVR

model=LinearSVR(max_iter=10000, C=10, epsilon=0.1)

model.fit(x_train,y_train_scaled)
# Out:
# LinearSVR(C=10, epsilon=0.1, max_iter=10000)

# %%
y_pred_test_scaled=model.predict(x_test)
y_pred_train_scaled=model.predict(x_train)

# evaluation 

print("for test r2_score is ",r2_score(y_test_scaled,y_pred_test_scaled))
print("for train r2_score is ",r2_score(y_train_scaled,y_pred_train_scaled))
# Out:
# for test r2_score is  0.4732121388673961
# for train r2_score is  0.5149920908009515
